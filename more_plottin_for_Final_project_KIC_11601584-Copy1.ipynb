# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# i need different plots for each planet
# day vs flux

# %%
import lightkurve as lk

# %%
#searching for light curves
# we want to find the light curve for Kepler 324, so we need to look up what its KIC ID is. We got "11601584" from the mikulski archive.
search_result = lk.search_lightcurve('KIC 11601584', author='Kepler') #(identify the target, author= the specific mission that will be returned.)
search_result

#returns a table with information I can download. The results say that KIC 11601584 was obsevered in quaters 1-17 of kepler.
# Out:
# SearchResult containing 17 data products.
#
#  #       mission      year author exptime  target_name  distance
#                                      s                   arcsec
# --- ----------------- ---- ------ ------- ------------- --------
#   0 Kepler Quarter 01 2009 Kepler    1800 kplr011601584      0.0
#   1 Kepler Quarter 02 2009 Kepler    1800 kplr011601584      0.0
#   2 Kepler Quarter 03 2009 Kepler    1800 kplr011601584      0.0
#   3 Kepler Quarter 04 2010 Kepler    1800 kplr011601584      0.0
#   4 Kepler Quarter 05 2010 Kepler    1800 kplr011601584      0.0
#   5 Kepler Quarter 06 2010 Kepler    1800 kplr011601584      0.0
#   6 Kepler Quarter 07 2010 Kepler    1800 kplr011601584      0.0
#   7 Kepler Quarter 10 2011 Kepler    1800 kplr011601584      0.0
#   8 Kepler Quarter 09 2011 Kepler    1800 kplr011601584      0.0
#   9 Kepler Quarter 13 2012 Kepler      60 kplr011601584      0.0
#  10 Kepler Quarter 13 2012 Kepler      60 kplr011601584      0.0
#  11 Kepler Quarter 11 2012 Kepler    1800 kplr011601584      0.0
#  12 Kepler Quarter 13 2012 Kepler    1800 kplr011601584      0.0
#  13 Kepler Quarter 14 2012 Kepler    1800 kplr011601584      0.0
#  14 Kepler Quarter 17 2013 Kepler      60 kplr011601584      0.0
#  15 Kepler Quarter 15 2013 Kepler    1800 kplr011601584      0.0
#  16 Kepler Quarter 17 2013 Kepler    1800 kplr011601584      0.0

# %%
lc = search_result.download()  # grabs the first available lightcurve file

# Plot the first light curve
lc.plot()
plt.show()
# Out:
# C:\Users\winx2\anaconda3\Lib\site-packages\lightkurve\search.py:420: LightkurveWarning: Warning: 17 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   warnings.warn(

# %%
#get the info for the lightcurve above
search_result[0] 
#select a single entry by indexing the result.
# Out:
# SearchResult containing 1 data products.
#
#  #       mission      year author exptime  target_name  distance
#                                      s                   arcsec
# --- ----------------- ---- ------ ------- ------------- --------
#   0 Kepler Quarter 01 2009 Kepler    1800 kplr011601584      0.0

# %%
#flatten the quater 1 light curve.
lc_flat = lc.flatten(window_length=401)  # remove long-term trends
lc_flat.plot()
plt.title("Flattened Light Curve")
plt.show()

# %%
#identify the transit period using BLS
from astropy.timeseries import BoxLeastSquares

# Extract time and flux arrays from the flattened light curve
time = lc_flat.time.value #time in days
flux = lc_flat.flux.value 

# Remove NaNs
mask = ~np.isnan(flux)
time = time[mask]
flux = flux[mask]

# Box Least Squares search
# BLS looks for periodic “box-shaped” dips in the light curve like transits
bls = BoxLeastSquares(time, flux)
periods = np.linspace(1, 30, 10000)  # search periods 1-30 days

# Run BLS to compute the “power” of transit-like signals for a range of periods
bls_results = bls.autopower(0.02)  #0.02 is the expected transit duration as a fraction of the period

best_period = bls_results.period[np.argmax(bls_results.power)] # Identify the period with the highest BLS power (most likely transit period)
print(f"Best-fit period: {best_period:.5f} days")
# Out:
# Best-fit period: 17.23251 days

# %%
# Fold the light curve. This aligns all the transits on top of each other. 
lc_fold = lc_flat.fold(period=best_period)
lc_fold.plot()
plt.title(f"Folded Light Curve (Period =  17.23251 days)")
plt.show()

# %%
#NEW QUATER (quater 3)

# %%
#now specify what data we want. I went with search result 3 for no particular reason. 
search_result_q3 = lk.search_lightcurve("KIC 11601584", mission="Kepler", quarter=3)
search_result_q3[0]
# Out:
# SearchResult containing 1 data products.
#
#  #       mission      year author exptime  target_name  distance
#                                      s                   arcsec
# --- ----------------- ---- ------ ------- ------------- --------
#   0 Kepler Quarter 03 2009 Kepler    1800 kplr011601584      0.0

# %%
#downloading a single light curve
lc = search_result_q3.download()
lc
# Out:
# <KeplerLightCurve length=4140 LABEL="KIC 11601584" QUARTER=3 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#        time             flux         flux_err          quality       ... mom_centr2_err   pos_corr1      pos_corr2
#                     electron / s   electron / s                      ...      pix            pix            pix
#        Time           float32        float32            int32        ...    float32        float32        float32
# ------------------ -------------- -------------- ------------------- ... -------------- -------------- --------------
#  260.2242802400724            ———            ———                   0 ...  2.3015958e-04 -2.3300355e-02  1.5147284e-02
#  260.2447134529939  3.0680984e+04  6.4022803e+00                   0 ...  2.3020680e-04 -2.3012146e-02  1.5091835e-02
#  260.2651465654417  3.0670418e+04  6.4029078e+00 1000000000000000000 ...  2.3018355e-04 -2.3035552e-02  1.5343181e-02
#   260.285579577896  3.0669436e+04  6.4016018e+00 1000010000000000000 ...  2.3025998e-04 -2.2957385e-02  1.5145782e-02
#   260.306012790119  3.0663797e+04  6.4032025e+00 1000000000000000000 ...  2.3023158e-04 -2.2812739e-02  1.5551528e-02
# 260.32644590233394  3.0669607e+04  6.4021997e+00 1000000000000000000 ...  2.3024311e-04 -2.3013471e-02  1.5194202e-02
#  260.3468789143226  3.0682248e+04  6.4039297e+00 1000000000000000000 ...  2.3015142e-04 -2.2899039e-02  1.5608768e-02
# 260.36731202607916  3.0677574e+04  6.4028587e+00 1000000000000000000 ...  2.3018163e-04 -2.2880919e-02  1.5511223e-02
#  260.3877452378292  3.0671648e+04  6.4033389e+00 1000000000000000000 ...  2.3022997e-04 -2.2742836e-02  1.5566308e-02
#  260.4081782491194  3.0676127e+04  6.4040155e+00 1000000000000000000 ...  2.3017282e-04 -2.2490345e-02  1.5990032e-02
#  260.4286113604103  3.0673666e+04  6.4014897e+00 1000000000000000000 ...  2.3018893e-04 -2.2426471e-02  1.5760826e-02
#  260.4490445716947  3.0674203e+04  6.4042635e+00 1100000000010000000 ...  2.3023342e-04 -2.2575796e-02  1.6037162e-02
#                ...            ...            ...                 ... ...            ...            ...            ...
#  349.2508092590215  3.0665951e+04  6.3983965e+00                   0 ...  2.3034221e-04  3.4458216e-02  8.8839017e-02
# 349.27124248305336  3.0656285e+04  6.3959770e+00                   0 ...  2.3040935e-04  3.4436807e-02  8.8991433e-02
#  349.2916755072074  3.0643994e+04  6.3980546e+00                   0 ...  2.3050350e-04  3.4394477e-02  8.8888906e-02
# 349.31210863159504  3.0658527e+04  6.3975039e+00                   0 ...  2.3036005e-04  3.4437772e-02  8.8927060e-02
# 349.33254165615654  3.0657930e+04  6.3975868e+00                   0 ...  2.3040548e-04  3.4525353e-02  8.9110389e-02
#  349.3529748808869  3.0668805e+04  6.3999643e+00                   0 ...  2.3031021e-04  3.4587633e-02  8.8988118e-02
#  349.3734080057984  3.0648426e+04  6.3967371e+00                   0 ...  2.3037453e-04  3.4400400e-02  8.9070968e-02
# 349.39384113087726  3.0657729e+04  6.3981004e+00                   0 ...  2.3034378e-04  3.4442395e-02  8.9157224e-02
#   349.414274256138  3.0656408e+04  6.3970032e+00                   0 ...  2.3041031e-04  3.4302574e-02  8.9235671e-02
#  349.4551405071834  3.0665139e+04  6.3983345e+00                   0 ...  2.3034391e-04  3.4760423e-02  8.9319229e-02
# 349.47557363296073  3.0671525e+04  6.3974075e+00                   0 ...  2.3036904e-04  3.4716159e-02  8.9292273e-02
#    349.49600675892  3.0665594e+04  6.3994436e+00                   0 ...  2.3033374e-04  3.4592982e-02  8.9382030e-02

# %%
#this returned a single object in the table above. It is also an astropy table so I conveverted the time and flux columns to a numpy array to make plotting eaiser.

# %%
lc.plot()
plt.show() #put plt.show because lc.plot was not working and it was just giving coordinates

# %%
#flatten the quater 3 light curve.
lc_flat = lc.flatten(window_length=401)  # remove long-term trends
lc_flat.plot()
plt.title("Flattened Light Curve")
plt.show()

# %%
#identify the transit period using BLS
from astropy.timeseries import BoxLeastSquares

# Extract time and flux arrays from the flattened light curve
time = lc_flat.time.value #time in days
flux = lc_flat.flux.value 

# Remove NaNs
mask = ~np.isnan(flux)
time = time[mask]
flux = flux[mask]

# Box Least Squares search
# BLS looks for periodic “box-shaped” dips in the light curve like transits
bls = BoxLeastSquares(time, flux)
periods = np.linspace(1, 30, 10000)  # search periods 1-30 days

# Run BLS to compute the “power” of transit-like signals for a range of periods
bls_results = bls.autopower(0.02)  #0.02 is the expected transit duration as a fraction of the period

best_period = bls_results.period[np.argmax(bls_results.power)] # Identify the period with the highest BLS power (most likely transit period)
print(f"Best-fit period: {best_period:.5f} days")
# Out:
# Best-fit period: 17.23251 days

# %%
# Fold the light curve.
lc_fold = lc_flat.fold(period=best_period)
lc_fold.plot()
plt.title(f"Folded Light Curve (Period =  17.23251 days)")
plt.show()

# %%
#got the exact same thing. this shows that the quater doesnt matter that much and for the rest of them im just going to use te first quater.

# %%
# time = lc['time']       # time in days
# flux = lc['flux']      # flux values

#make a scatter plot

time = lc['time'].value           # strip units by using '.value' and turn them into numpy arrays,and # time in days
flux = lc['flux'].value  


plt.scatter(time, flux, s=1, color='lightseagreen', label='Kepler-324(quarter 3)')
plt.title('Kepler-324 Light Curve')
plt.xlabel('Time [days]')
plt.ylabel('Flux')
plt.legend()
plt.show()

# %%
#new quater: graph using kepler quarter 2

# %%
search_result_q2 = lk.search_lightcurve("KIC 11601584", mission="Kepler", quarter=2)
search_result_q2[0]
# Out:
# SearchResult containing 1 data products.
#
#  #       mission      year author exptime  target_name  distance
#                                      s                   arcsec
# --- ----------------- ---- ------ ------- ------------- --------
#   0 Kepler Quarter 02 2009 Kepler    1800 kplr011601584      0.0

# %%
lc = search_result_q2.download()
lc
# Out:
# C:\Users\winx2\anaconda3\Lib\site-packages\lightkurve\search.py:420: LightkurveWarning: Warning: 2 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   warnings.warn(
# <KeplerLightCurve length=4075 LABEL="KIC 11601584" QUARTER=2 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#        time             flux         flux_err        quality      ... mom_centr2_err   pos_corr1      pos_corr2
#                     electron / s   electron / s                   ...      pix            pix            pix
#        Time           float32        float32          int32       ...    float32        float32        float32
# ------------------ -------------- -------------- ---------------- ... -------------- -------------- --------------
# 169.76498169376282  3.1042389e+04  6.0466747e+00   10000000000000 ...  2.5621537e-04 -6.0412763e-03  1.4842521e-01
#  169.7854157902766  3.1039578e+04  6.0476537e+00                0 ...  2.5626202e-04 -5.9787524e-03  1.4846398e-01
# 169.80584968655603  3.1051080e+04  6.0474391e+00                0 ...  2.5609499e-04 -6.0496079e-03  1.4845814e-01
# 169.82628378259687  3.1269230e+04  6.1013508e+00         10000000 ...  2.5623036e-04 -6.3265297e-03  1.4794968e-01
# 169.84671767841064  3.1033406e+04  6.0467477e+00         10000000 ...  2.5629345e-04 -6.1818697e-03  1.4793785e-01
# 169.86715177422593  3.1040051e+04  6.0496178e+00                0 ...  2.5627782e-04 -6.2396498e-03  1.4848702e-01
#  169.8875856697996  3.1033615e+04  6.0449190e+00                0 ...  2.5634503e-04 -6.2279990e-03  1.4789818e-01
# 169.90801966514846  3.1035979e+04  6.0487361e+00                0 ...  2.5635058e-04 -6.4100586e-03  1.4794837e-01
#  169.9284537604981  3.1029445e+04  6.0488472e+00                0 ...  2.5638711e-04 -6.4717345e-03  1.4758314e-01
# 169.94888765537326  3.1039221e+04  6.0471277e+00                0 ...  2.5634939e-04 -6.4171040e-03  1.4756624e-01
# 169.96932165025646  3.1030236e+04  6.0460701e+00                0 ...  2.5632480e-04 -6.4981659e-03  1.4771464e-01
# 169.98975574514043  3.1036080e+04  6.0498734e+00                0 ...  2.5629101e-04 -6.7230542e-03  1.4752673e-01
#                ...            ...            ...              ... ...            ...            ...            ...
# 258.22185643127887  3.1057281e+04  6.0238247e+00                0 ...  2.7081923e-04 -2.5890313e-02 -1.4699538e-01
#  258.2422894600313  3.1062354e+04  6.0233889e+00                0 ...  2.7096560e-04 -2.6407575e-02 -1.4767502e-01
#  258.2627226883196  3.1044961e+04  6.0222397e+00                0 ...  2.7114229e-04 -2.7088424e-02 -1.4931574e-01
#  258.2831558166072  3.1058842e+04  6.0227375e+00                0 ...  2.7095462e-04 -2.7123559e-02 -1.4851069e-01
#  258.3035888448867  3.1066295e+04  6.0230932e+00                0 ...  2.7085189e-04 -2.6654622e-02 -1.4755711e-01
# 258.32402207270934  3.1061664e+04  6.0220885e+00                0 ...  2.7097028e-04 -2.7082138e-02 -1.4913559e-01
# 258.34445520052395  3.1053855e+04  6.0228648e+00                0 ...  2.7099601e-04 -2.6771957e-02 -1.4866768e-01
# 258.36488822811225  3.1052277e+04  6.0232997e+00                0 ...  2.7094796e-04 -2.6228331e-02 -1.4706665e-01
#  258.4057545830583  3.1057635e+04  6.0224400e+00                0 ...  2.7093617e-04 -2.7395062e-02 -1.4970367e-01
# 258.42618761017366  3.1044266e+04  6.0218062e+00                0 ...  2.7121694e-04 -2.6735781e-02 -1.4894320e-01
#  258.4466207370642  3.1048877e+04  6.0224509e+00                0 ...  2.7098347e-04 -2.6516160e-02 -1.4770114e-01
#  258.4670539639483  3.1055918e+04  6.0226145e+00                0 ...  2.7095966e-04 -2.6309865e-02 -1.4811425e-01

# %%
lc.plot()
plt.show()

# %%
flat_lc = lc.normalize().flatten(window_length=401)
flat_lc.plot()
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Normalized Flux'>

# %%
lc_collection = search_result[:17].download_all()
lc_collection
# Out:
# LightCurveCollection of 17 objects:
#     0: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=1 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     1: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=2 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     2: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=3 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     3: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=4 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     4: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=5 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     5: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=6 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     6: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=7 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     7: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=10 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     8: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=9 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     9: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=13 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     10: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=13 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     11: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=11 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     12: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=13 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     13: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=14 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     14: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=17 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     15: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=17 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     16: <KeplerLightCurve LABEL="KIC 11601584" QUARTER=15 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>

# %%
#he tutorial on combining multiple quarters of Kepler observations.

# %%
# make a larger figure to be able to see everything
fig, ax = plt.subplots(figsize=(20,20))
# Plot the light curves (quaters 1-5)
lc_collection.plot(ax=ax);
plt.show()
#the quarters are a 3-month segment of observations of the same star
#the transits are the small dips within each quarter.

# %%
# Measure transit depth for all transits
depths = []
transit_centers = bls_results.transit_time[np.argmax(bls_results.power)]
duration = bls_results.duration[np.argmax(bls_results.power)]

# Identify individual transits
phase = (lc_fold.time.value - transit_centers + 0.5*best_period) % best_period - 0.5*best_period
in_transit = np.abs(phase) < duration/2
transit_fluxes = lc_fold.flux.value[in_transit]

# Average depth (fractional dip)
depth = 1 - np.min(transit_fluxes)
Rp_Rs = np.sqrt(depth)
print(f"Estimated planet radius / star radius: {Rp_Rs:.5f}")
# Out:
# Estimated planet radius / star radius: 0.02499

# %%
# Plot depth variation for the multiple transits
# Split the light curve into individual transits
num_transits = int((time[-1] - time[0]) / best_period)
transit_depths = []

for n in range(num_transits):
    t0 = transit_centers + n*best_period
    mask_transit = (time > t0 - duration/2) & (time < t0 + duration/2)
    if np.any(mask_transit):
        flux_transit = flux[mask_transit]
        depth_n = 1 - np.min(flux_transit)
        transit_depths.append(depth_n)

# Plot variation
plt.plot(range(len(transit_depths)), transit_depths, marker='o')
plt.xlabel("Transit number")
plt.ylabel("Transit depth")
plt.title("Transit Depth Variation")
plt.show()
