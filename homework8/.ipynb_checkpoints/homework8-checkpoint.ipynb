# %%
import pandas as pd

# %%
df = pd.read_csv('state_data.csv')
print(df)
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_csv('state_data.csv')
#       2 print(df)
#       3 print(df.shape)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'state_data.csv'

# %%
#4 columns and 52 rows

# %%
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(df.head())
#
# NameError: name 'df' is not defined

# %%
print(df.tail())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(df.tail())
#
# NameError: name 'df' is not defined

# %%
# #the columms are the different categorize.
# the first state is alaska
# the last state is wyoming
# there are 52 entries total
# there is more than 50 because there is probably a duplicate

# %%
df['latitude'].median()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df['latitude'].median()
#
# NameError: name 'df' is not defined

# %%
df['longitude'].median()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['longitude'].median()
#
# NameError: name 'df' is not defined

# %%
median_latitude=df['latitude'].median()
df['absolute_distance_to_median_latitude']= (df['latitude']-median_latitude).abs()
df.head()
#I dont know why its making two coloumns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 median_latitude=df['latitude'].median()
#       2 df['absolute_distance_to_median_latitude']= (df['latitude']-median_latitude).abs()
#       3 df.head()
#
# NameError: name 'df' is not defined

# %%
median_longitude=df['longitude'].median()
df['absolute_distance_to_median_longitude']= (df['longitude']-median_longitude).abs()
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 median_longitude=df['longitude'].median()
#       2 df['absolute_distance_to_median_longitude']= (df['longitude']-median_longitude).abs()
#       3 df.head()
#
# NameError: name 'df' is not defined

# %%
df.shape
#52 rows and 7 columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
closest_latitude=df.loc[df['absolute_distance_to_median_latitude'].idxmin()]
print(closest_latitude)
print(f"{closest_latitude['absolute_distance_to_median_latitude']:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 closest_latitude=df.loc[df['absolute_distance_to_median_latitude'].idxmin()]
#       2 print(closest_latitude)
#       3 print(f"{closest_latitude['absolute_distance_to_median_latitude']:.2f}")
#
# NameError: name 'df' is not defined

# %%
farthest_latitude=df.loc[df['absolute_distance_to_median_latitude'].idxmax()]
print(farthest_latitude)
print(f"{farthest_latitude['absolute_distance_to_median_latitude']:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 farthest_latitude=df.loc[df['absolute_distance_to_median_latitude'].idxmax()]
#       2 print(farthest_latitude)
#       3 print(f"{farthest_latitude['absolute_distance_to_median_latitude']:.2f}")
#
# NameError: name 'df' is not defined

# %%
closest_longitude=df.loc[df['absolute_distance_to_median_longitude'].idxmin()]
print(closest_longitude)
print(f"{closest_longitude['absolute_distance_to_median_longitude']:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 closest_longitude=df.loc[df['absolute_distance_to_median_longitude'].idxmin()]
#       2 print(closest_longitude)
#       3 print(f"{closest_longitude['absolute_distance_to_median_longitude']:.2f}")
#
# NameError: name 'df' is not defined

# %%
farthest_longitude=df.loc[df['absolute_distance_to_median_longitude'].idxmax()]
print(farthest_longitude)
print(f"{farthest_longitude['absolute_distance_to_median_longitude']:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 farthest_longitude=df.loc[df['absolute_distance_to_median_longitude'].idxmax()]
#       2 print(farthest_longitude)
#       3 print(f"{farthest_longitude['absolute_distance_to_median_longitude']:.2f}")
#
# NameError: name 'df' is not defined

# %%
# using pandas.pivot
df.pivot(index='state', columns='latitude', values='names')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # using pandas.pivot
# ----> 2 df.pivot(index='state', columns='latitude', values='names')
#
# NameError: name 'df' is not defined
